# %%
# %matplotlib inline
import requests
import json 
import matplotlib.pyplot as plt
import pandas
from datetime import datetime
import seaborn as sns
import glob
from os.path import basename
sns.set_context('poster')
import re
import itertools

# %%
#convention_speeches = glob.glob('../results/receptiviti/convention/*')
#inaug_speeches = glob.glob('../results/receptiviti/inaug/*')
sotu_speeches = glob.glob('../results/receptiviti/SOTU/*')

# %%
print "\n".join(sotu_speeches)
# Out:
# ../results/receptiviti/SOTU/clinton-sotu-1993.json
# ../results/receptiviti/SOTU/clinton-sotu-1994.json
# ../results/receptiviti/SOTU/clinton-sotu-1995.json
# ../results/receptiviti/SOTU/clinton-sotu-1996.json
# ../results/receptiviti/SOTU/clinton-sotu-1998.json
# ../results/receptiviti/SOTU/clinton-sotu-1999.json
# ../results/receptiviti/SOTU/clinton-sotu-2000.json
# ../results/receptiviti/SOTU/gwbush-sotu-2001.json
# ../results/receptiviti/SOTU/gwbush-sotu-2002.json
# ../results/receptiviti/SOTU/gwbush-sotu-2003.json
# ../results/receptiviti/SOTU/gwbush-sotu-2004.json
# ../results/receptiviti/SOTU/gwbush-sotu-2006.json
# ../results/receptiviti/SOTU/gwbush-sotu-2007.json
# ../results/receptiviti/SOTU/gwbush-sotu-2008.json
# ../results/receptiviti/SOTU/hwbush-sotu-1989.json
# ../results/receptiviti/SOTU/obama-sotu-2009.json
# ../results/receptiviti/SOTU/obama-sotu-2010.json
# ../results/receptiviti/SOTU/obama-sotu-2011.json
# ../results/receptiviti/SOTU/obama-sotu-2012.json
# ../results/receptiviti/SOTU/obama-sotu-2013.json
# ../results/receptiviti/SOTU/obama-sotu-2014.json
# ../results/receptiviti/SOTU/obama-sotu-2015.json
# ../results/receptiviti/SOTU/obama-sotu-2016.json
# ../results/receptiviti/SOTU/reagan-sotu-1981.json

# %%
dataframes = []
 
for speech in sotu_speeches:
    print speech
    j = json.load(open(speech)) 
    fields = {k:v for k,v in j['liwc_scores'].iteritems() if k != 'categories'}
    fields.update(j['liwc_scores']['categories']) 
    df = pandas.DataFrame.transpose(pandas.DataFrame.from_dict(fields, orient='index'))
    df['president'] = re.findall('(\w+)-.+', basename(speech))
    df['type'] = re.findall('.+-(\w+)-.+', basename(speech))
    df['year'] = re.findall('.+-(\d+).+', basename(speech))
    df['speechname'] = basename(speech).replace('.json', '')
    dataframes.append(df)
# Out:
# ../results/receptiviti/SOTU/clinton-sotu-1993.json
# ../results/receptiviti/SOTU/clinton-sotu-1994.json
# ../results/receptiviti/SOTU/clinton-sotu-1995.json
# ../results/receptiviti/SOTU/clinton-sotu-1996.json
# ../results/receptiviti/SOTU/clinton-sotu-1998.json
# ../results/receptiviti/SOTU/clinton-sotu-1999.json
# ../results/receptiviti/SOTU/clinton-sotu-2000.json
# ../results/receptiviti/SOTU/gwbush-sotu-2001.json
# ../results/receptiviti/SOTU/gwbush-sotu-2002.json
# ../results/receptiviti/SOTU/gwbush-sotu-2003.json
# ../results/receptiviti/SOTU/gwbush-sotu-2004.json
# ../results/receptiviti/SOTU/gwbush-sotu-2006.json
# ../results/receptiviti/SOTU/gwbush-sotu-2007.json
# ../results/receptiviti/SOTU/gwbush-sotu-2008.json
# ../results/receptiviti/SOTU/hwbush-sotu-1989.json
# ../results/receptiviti/SOTU/obama-sotu-2009.json
# ../results/receptiviti/SOTU/obama-sotu-2010.json
# ../results/receptiviti/SOTU/obama-sotu-2011.json
# ../results/receptiviti/SOTU/obama-sotu-2012.json
# ../results/receptiviti/SOTU/obama-sotu-2013.json
# ../results/receptiviti/SOTU/obama-sotu-2014.json
# ../results/receptiviti/SOTU/obama-sotu-2015.json
# ../results/receptiviti/SOTU/obama-sotu-2016.json
# ../results/receptiviti/SOTU/reagan-sotu-1981.json

# %%
df = pandas.concat(dataframes)
df = df.set_index('speechname',drop=True)
df.to_csv('../results/receptiviti/master/all-sotu.csv')

# %%
df.type
# Out:
# speechname
# clinton-sotu-1993    sotu
# clinton-sotu-1994    sotu
# clinton-sotu-1995    sotu
# clinton-sotu-1996    sotu
# clinton-sotu-1998    sotu
# clinton-sotu-1999    sotu
# clinton-sotu-2000    sotu
# gwbush-sotu-2001     sotu
# gwbush-sotu-2002     sotu
# gwbush-sotu-2003     sotu
# gwbush-sotu-2004     sotu
# gwbush-sotu-2006     sotu
# gwbush-sotu-2007     sotu
# gwbush-sotu-2008     sotu
# hwbush-sotu-1989     sotu
# obama-sotu-2009      sotu
# obama-sotu-2010      sotu
# obama-sotu-2011      sotu
# obama-sotu-2012      sotu
# obama-sotu-2013      sotu
# obama-sotu-2014      sotu
# obama-sotu-2015      sotu
# obama-sotu-2016      sotu
# reagan-sotu-1981     sotu
# Name: type, dtype: object

# %%
df[df.type=='convention'].sort_values('tone').tone.plot()
plt.xticks(rotation=50)
plt.ylabel('Negative to Positive')
plt.ylim([0,100])
plt.xlabel('')
plt.title("Emotional tone, all convention speeches")
plt.savefig('../figs/trajectories/all-conventions-tone-ranked.png')

# %%
df[df.type=='inaug'].sort_values('tone').tone.plot()
plt.xticks(rotation=50)
plt.ylabel('Negative to Positive')
plt.ylim([0,100])
plt.xlabel('')
plt.title("Emotional tone, all inaugural speeches")
plt.savefig('../figs/trajectories/all-inaug-tone-ranked.png')

# %%
 df[df.type=='sotu'].sort_values('tone').tone.plot()
plt.xticks(rotation=50)
plt.ylabel('Negative to Positive')
plt.ylim([0,100])
plt.xlabel('')
plt.title("Emotional tone, all SOTU speeches")
plt.savefig('../figs/trajectories/all-sotu-tone-ranked.png')

# %%
df[df.type=='convention'].sort_values('authentic').authentic.plot()
plt.xticks(rotation=50)
plt.ylabel('Negative to Positive')
plt.ylim([0,100])
plt.xlabel('')
plt.title("Authenticity, all convention speeches")
plt.savefig('../figs/trajectories/all-sotu-auth-ranked.png')

# %%
df[df.type=='inaug'].sort_values('authentic').authentic.plot()
plt.xticks(rotation=50)
plt.ylabel('Negative to Positive')
plt.ylim([0,100])
plt.xlabel('')
plt.title("Authenticity, all inaugural speeches")
plt.savefig('../figs/trajectories/all-inaug-auth-ranked.png')

# %%
df[df.type=='sotu'].sort_values('authentic').authentic.plot()
plt.xticks(rotation=50)
plt.ylabel('Negative to Positive')
plt.ylim([0,100])
plt.xlabel('')
plt.title("Authenticity, all SOTU speeches")
plt.savefig('../figs/trajectories/all-sotu-auth-ranked.png')

# %%
df.head()
# Out:
#                               tone    family      feel     money   insight  \
# speechname
# clinton-convention-1992  65.464195  0.012165  0.004280  0.016896  0.014418
# clinton-inaug-1993       79.714310  0.001892  0.004414  0.009458  0.015132
# clinton-sotu-1993        70.439790  0.002416  0.001848  0.044059  0.014497
# gwbush-convention-2000   88.050860  0.006052  0.004357  0.016703  0.020576
# gwbush-inaug-2001        88.809395  0.001899  0.001899  0.005063  0.015823
#
#                            number     clout  Parenth   cogproc    OtherP  \
# speechname
# clinton-convention-1992  0.011264  86.91031      0.0  0.108358  0.000225
# clinton-inaug-1993       0.005675  96.11114      0.0  0.102144  0.000000
# clinton-sotu-1993        0.020182  82.73636      0.0  0.108584  0.003553
# gwbush-convention-2000   0.009199  84.36764      0.0  0.106270  0.000484
# gwbush-inaug-2001        0.001899  92.35746      0.0  0.120253  0.000000
#
#                          ...     posemo    ingest      Dash     swear  \
# speechname               ...
# clinton-convention-1992  ...   0.037396  0.000901  0.008110  0.000000
# clinton-inaug-1993       ...   0.046658  0.000000  0.001892  0.000000
# clinton-sotu-1993        ...   0.039227  0.000284  0.003695  0.000000
# gwbush-convention-2000   ...   0.054224  0.001452  0.004599  0.000484
# gwbush-inaug-2001        ...   0.066456  0.000000  0.000633  0.000000
#
#                             Comma      time    reward  president        type  \
# speechname
# clinton-convention-1992  0.061275  0.054967  0.014643    clinton  convention
# clinton-inaug-1993       0.074401  0.059899  0.012610    clinton       inaug
# clinton-sotu-1993        0.049034  0.054292  0.013076    clinton        sotu
# gwbush-convention-2000   0.065602  0.054466  0.016461     gwbush  convention
# gwbush-inaug-2001        0.072785  0.047468  0.012658     gwbush       inaug
#
#                          year
# speechname
# clinton-convention-1992  1992
# clinton-inaug-1993       1993
# clinton-sotu-1993        1993
# gwbush-convention-2000   2000
# gwbush-inaug-2001        2001
#
# [5 rows x 96 columns]
